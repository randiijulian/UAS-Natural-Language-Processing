# %% [markdown]
# <a href="https://colab.research.google.com/github/randiijulian/UAS-Natural-Language-Processing/blob/main/SMS_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Randi Julian Saputra
#
# Github : github.com/randiijulian
#
# ## UAS Mata Kuliah Natural Language Processing
# SMS Classification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import Libraries

# %%
# Mamasukan Library yang diperlukan
import pandas as pd
import numpy as np

# visualisasi
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style='darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Import Dataset

# %%
# # Load Dataset
home_data = pd.read_excel("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Dataset/Dataset SMS 1.xlsx")
# home_data = pd.read_excel("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Dataset/Dataset gabungan.xlsx")
home_data.head()
# Load Dataset
# home_data = pd.read_excel("/content/Dataset SMS.xlsx")
# home_data.head()
# Out:
#    Kategori                                               Text
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...

# %% [markdown]
# ### Data Cleansing

# %%
# Periksa SMS Text Non Spam
home_data[home_data['Kategori']=='Non Spam'].head()
# Out:
#    Kategori                                               Text
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...

# %%
# Periksa SMS Text Spam
home_data[home_data['Kategori']=='Spam'].head()
# Out:
#      Kategori                                               Text
# 1844     Spam  SELAMAT KAMU DAPAT KUOTA GRATIS! Ada 7.5GB gra...
# 1845     Spam  SELAMAT! GRATIS kuota hingga 50GB bisa kamu am...
# 1846     Spam  SELAMAT! GRATIS kuota hingga 50GB bisa kamu am...
# 1847     Spam  SELAMAT! GRATIS kuota hingga 50GB bisa kamu am...
# 1848     Spam  SELAMAT! GRATIS hingga 100GB bisa kamu dapetin...

# %%
# Periksa SMS Text Penipuan
home_data[home_data['Kategori']=='Penipuan'].head()
# Out:
#       Kategori                                               Text
# 4200  Penipuan  4nda terpilih dapatkan hadiah 75.000.000 dri T...
# 4201  Penipuan  Slmt and4 terpilih. . . . Men-d4p4t cek 189 jt...
# 4202  Penipuan  Team #IndonesiaG!ve@way  Menyampaikan anda ter...
# 4203  Penipuan  INFO TERAHIR!! Slmt No SIM CADR Anda Mendapt-k...
# 4204  Penipuan  Anda Resmi M-dapatkan cek tunai Dari PT.SHOPEE...

# %%
# Describe Dataset
home_data.describe()
# Out:
#        Kategori                                               Text
# count      4969                                               4969
# unique        3                                               3219
# top        Spam  Mohon maaf pulsa anda tidak mencukupi. Harap T...
# freq       2356                                                 57

# %%
home_data.info()

# %%
# check missing value
home_data.isnull().sum().sort_values(ascending=False)
# Out:
# Kategori    0
# Text        0
# dtype: int64

# %%
# Class Distribution
print(home_data['Kategori'].value_counts())
print('\n')
print(sns.countplot(home_data['Kategori']))
# Out:
# Spam        2356
# Non Spam    1844
# Penipuan     769
# Name: Kategori, dtype: int64
#
#
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# Persentase Banyak Data
total_Non_Spam = home_data[home_data['Kategori']=='Non Spam']['Kategori'].count()
total_Spam = home_data[home_data['Kategori']=='Spam']['Kategori'].count()
total_Penipuan = home_data[home_data['Kategori']=='Penipuan']['Kategori'].count()

percent_Non_Spam = (total_Non_Spam/(total_Non_Spam+total_Spam+total_Penipuan)*100)
percent_Spam = (total_Spam/(total_Non_Spam+total_Spam+total_Penipuan)*100)
percent_Penipuan= (total_Penipuan/(total_Non_Spam+total_Spam+total_Penipuan)*100)
print(percent_Non_Spam, '%')
print(percent_Spam, '%')
print(percent_Penipuan, '%')
# Out:
# 37.11008251157175 %
# 47.41396659287583 %
# 15.475950895552426 %

# %%
home_data['Length'] = home_data['Text'].apply(len)
home_data.hist(column='Length', by='Kategori', bins=30, figsize=(22,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe6870fd370>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe6871187c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe6870bebe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe68707a040>]],
#       dtype=object)

# %% [markdown]
# ### Preprocessing Data
# preprocessing data untuk menghilangkan kata-kata yang tidak penting serta menjadikan setiap kata menjadi lower case serta melakukan pengolahan pada data

# %%
# Tahap Preprocessing Data

import re

def praproses(home_data):
  texts = []

  for text in home_data:
    # Menghapus @name[mention]
    text = re.sub(r"(?:\@|https?\://)\S+", "", text)

    text = re.sub(r"www(.|,)(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", "", text)


    # Menghapus link bit.ly
    text = re.sub(r"(B|b)(I|i)(T|t)(.|,)(L|l|)(Y|y|v)(/|//)(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", "", text)

    # Menghapus links[https://blabala.com]
    text = re.sub(r"http[s]?(:|;)//(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", "", text)
    # text = re.sub(r"http\S+", "", text)

    # Menghapus rp
    text = re.sub(r'(RP|Rp|rp|rP)', '', text)

    # Menghapus gb
    text = re.sub(r'(RB|Rb|rb|rB)', '', text)

    # Menghapus Gb
    text = re.sub(r'(GP|Gp|gp|gP)', '', text)

    # Menghapus Jt
    text = re.sub(r'(JT|Jt|jt|jT)', '', text)

    # Menghapus trx
    text = re.sub(r'(Trx|TRX)', '', text)

    # Menghapus enter / baris baru
    text = re.sub('\n', '', text)

    # Menghapus tanda baca dan angka
    text = re.sub("[^a-zA-Z^']", " ", text)
    text = re.sub(" {2,}", " ", text)

    # Menghapus spasi awal dan akhir
    text = text.strip()

    # Menghapus spasi dengan satu spasi
    text = re.sub(r"\s+", " ", text)

    # Menghapus link www.
    # text = re.sub(r'www.(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))', '', text)

    # Mengubah mennjadi text kecil (lower)
    text = text.lower();
    texts.append(text)
  return texts

# %%
# Periksa data setelah preproccesing
home_data['Praproses']=praproses(home_data['Text'])
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam      40
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...     124
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah      43
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...

# %%
# home_data.to_csv("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Dataset/Coba.csv", index=False)

# %% [markdown]
# #### Tokenizing

# %%
# Tokenisasi
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
def token(home_data):
  return home_data.apply(nltk.word_tokenize)

# %%
# Periksa data setelah tokenisai
home_data['Token']=token(home_data['Praproses'])
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam      40
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...     124
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah      43
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...

# %% [markdown]
# #### Stemming

# %%
# Stemming
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 4.9 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
def stemming(home_data):
  factory = StemmerFactory()
  stemmer = factory.create_stemmer()

  return [stemmer.stem(text) for text in home_data]

# %%
# Periksa data setelah Steming
home_data['Stemmed'] = home_data['Token'].apply(stemming)
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam      40
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...     124
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah      43
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...

# %% [markdown]
# #### Replace Slang Words
# tahapan ini mengubah beberapa kata gaul atau slang word ke bahasa baku

# %%
# Mengubah Kata kata Gaul
import requests

# %%
slang_word = requests.get('https://raw.githubusercontent.com/louisowen6/NLP_bahasa_resources/master/combined_slang_words.txt').text
dict_slang = eval(slang_word)

# %%
# Periksa Kata gaul yang di ubah
slang_df = pd.DataFrame(dict_slang.items(), columns=['Old', 'New'])
slang_df.head()
# Out:
#      Old               New
# 0      @                di
# 1   abis             habis
# 2     ad               ada
# 3   adlh            adalah
# 4  afaik  as far as i know

# %%
# Menghapus Spasi yang tersisa
slang_df['Old'] = slang_df['Old'].apply(lambda x: x.strip())
slang_df['New'] = slang_df['New'].apply(lambda x: x.strip())

# %%
# Mengubah ke nilai kunci
slang_dict = {}
for i, row in slang_df.iterrows():
  slang_dict.update({row['Old']: row['New']})

# %%
def removeSlang(data):
  # Iterasi data
  for i, word in enumerate(data):
    # memeriksa data didalam kamus slang(kata gaul) atau tidak
    try:
      data[i] = slang_dict[word]
    # jika data tidak gaul maka lulus
    except KeyError:
      pass
  return data

# %%
home_data['Tidak_Gaul'] = home_data['Stemmed'].apply(removeSlang)
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam      40
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...     124
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah      43
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                           Tidak_Gaul
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...

# %% [markdown]
# #### Stop Word

# %%
# Stop Word Removal
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def removeStopWords(data):
  stop_words = set(stopwords.words('indonesian'))
  return data.apply(lambda x: [item for item in x if item not in stop_words])

# %%
# Periksa Data Seletah Stop Word Removal
home_data['No_Stop']=removeStopWords(home_data['Tidak_Gaul'])
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0  Non Spam           Hoaks itu jahat! Kesehatan kita terancam      40
# 1  Non Spam  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2  Non Spam  Hambat varian Omicron di Indonesia dengan disi...     124
# 3  Non Spam        Walau sudah boleh berkegiatan di luar rumah      43
# 4  Non Spam  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                           Tidak_Gaul  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              No_Stop
# 0                       [hoaks, jahat, sehat, ancam]
# 1        [covid, gelombang, waspada, vaksin, vaksin]
# 2  [hambat, varian, omicron, indonesia, disiplin,...
# 3                                      [giat, rumah]
# 4  [vaksinasi, lengkap, booster, disiplin, prokes...

# %%
# Pengkodean Nilai Kategori
# home_data['Kategori'] = home_data['Kategori'].apply(lambda x: 1 if x == 'Non Spam' else 0)
home_data['Kategori'] = home_data['Kategori'].apply(lambda x: 1 if x == 'Non Spam' else (2 if x == 'Spam' else 3))
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0         1           Hoaks itu jahat! Kesehatan kita terancam      40
# 1         1  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2         1  Hambat varian Omicron di Indonesia dengan disi...     124
# 3         1        Walau sudah boleh berkegiatan di luar rumah      43
# 4         1  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                           Tidak_Gaul  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              No_Stop
# 0                       [hoaks, jahat, sehat, ancam]
# 1        [covid, gelombang, waspada, vaksin, vaksin]
# 2  [hambat, varian, omicron, indonesia, disiplin,...
# 3                                      [giat, rumah]
# 4  [vaksinasi, lengkap, booster, disiplin, prokes...

# %%
# Menggabungkan kata yang sudah dibersihkan
home_data['Bersih'] = home_data['No_Stop'].apply(lambda x: ' '.join(x))
home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0         1           Hoaks itu jahat! Kesehatan kita terancam      40
# 1         1  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2         1  Hambat varian Omicron di Indonesia dengan disi...     124
# 3         1        Walau sudah boleh berkegiatan di luar rumah      43
# 4         1  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                           Tidak_Gaul  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              No_Stop  \
# 0                       [hoaks, jahat, sehat, ancam]
# 1        [covid, gelombang, waspada, vaksin, vaksin]
# 2  [hambat, varian, omicron, indonesia, disiplin,...
# 3                                      [giat, rumah]
# 4  [vaksinasi, lengkap, booster, disiplin, prokes...
#
#                                               Bersih
# 0                            hoaks jahat sehat ancam
# 1              covid gelombang waspada vaksin vaksin
# 2  hambat varian omicron indonesia disiplin pakai...
# 3                                         giat rumah
# 4  vaksinasi lengkap booster disiplin prokes lind...

# %%
# Menggabungkan Text dan Kategori yang Dibersihkan
data1 = home_data[['Bersih']]
data2 = home_data[['Kategori']]
data_bersih = pd.concat([data1, data2], axis=1)
data_bersih.head()
# Out:
#                                               Bersih  Kategori
# 0                            hoaks jahat sehat ancam         1
# 1              covid gelombang waspada vaksin vaksin         1
# 2  hambat varian omicron indonesia disiplin pakai...         1
# 3                                         giat rumah         1
# 4  vaksinasi lengkap booster disiplin prokes lind...         1

# %%
data_bersih.tail()
# Out:
#                                                  Bersih  Kategori
# 4964  mndptkan subsid perintah code informasi resmi ...         3
# 4965  team indonesiag ve teilh terima g ve kode pin ...         3
# 4966  s l m t m dptkan h h cek sho pe e kode id blw ...         3
# 4967  split bill hafidotul alfiah tuju kirim uang ko...         3
# 4968         resmi m cek tunai pt shopee pin f inf klik         3

# %% [markdown]
# ### Text Vectorizer

# %%
# Text Vectorizer (Pembobotan Kata) TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
X = data_bersih['Bersih']
kategori = data_bersih['Kategori']

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_vector = tfidf_vectorizer.fit_transform(X)
tfidf_vector.shape
# Out:
# (4969, 5708)

# %%
# Menyeimbangakan Data Yang Tidak Sama Jumlahnya
from imblearn.over_sampling import SMOTE

# %%
sampler = SMOTE()
tfidf_vector, kategori = sampler.fit_resample(tfidf_vector, kategori)
print(tfidf_vector.shape)
print(kategori.shape)
# Out:
# (7068, 5708)
# (7068,)

# %% [markdown]
# ### Splitting Data

# %%
# Split Data (Data Training dan Testing)
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_vector, kategori, test_size=0.2, shuffle=True, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5654, 5708)
# (1414, 5708)
# (5654,)
# (1414,)

# %%
# Kata-Kata Umum dan Kata Kata Penting
feature_names = np.array(tfidf_vectorizer.get_feature_names())

# Sort TFIDF by value
max_tf_idfs = X_train.max(0).toarray()[0] # Get largest tfidf values across all documents.
sorted_tf_idxs = max_tf_idfs.argsort() # Sorted indices
sorted_tf_idfs = max_tf_idfs[sorted_tf_idxs] # Sorted TFIDF values

# feature_names doesn't need to be sorted! You just access it with a list of sorted indices!
smallest_tf_idfs = pd.Series(sorted_tf_idfs[:10], index=feature_names[sorted_tf_idxs[:10]])                    
largest_tf_idfs = pd.Series(sorted_tf_idfs[-10:][::-1], index=feature_names[sorted_tf_idxs[-10:][::-1]])

# %% [markdown]
# ### Word Cloud

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image

# %%
# Non Spam Wordcloud
Non_Spam = ' '.join([word for word in home_data['Bersih'][data_bersih['Kategori']==1]])
wordcloud = WordCloud(width=400, height=300, max_font_size=100).generate(Non_Spam)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Spam Wordcloud
Spam = ' '.join([word for word in home_data['Bersih'][data_bersih['Kategori']==2]])
wordcloud = WordCloud(width=400, height=300, max_font_size=100).generate(Spam)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Penipuan Wordcloud
Penipuan = ' '.join([word for word in home_data['Bersih'][data_bersih['Kategori']==3]])
wordcloud = WordCloud(width=400, height=300, max_font_size=100).generate(Penipuan)
plt.figure(figsize=(12,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Save new dataframe into csv file
home_data.to_csv("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Dataset/Dataset SMS Clean.csv", index=False)
# Save new dataframe into csv file
# home_data.to_csv("/content/Dataset SMS Clean.csv", index=False)

# %% [markdown]
# ### Modeling

# %%
# Modeling
from mlxtend.plotting import plot_confusion_matrix
from sklearn import metrics

# %%
def print_conf(y_test, result, classes, title='Confusion matrix'):
  conf_matrix = metrics.confusion_matrix(y_test, result)
  plt.figure(figsize=(6,6))
  sns.heatmap(conf_matrix, 
              annot=True,
              xticklabels=classes, 
              yticklabels=classes,
              cmap="Blues",
              fmt='d')
  plt.ylabel('Actual')
  plt.xlabel('Predicted')
  plt.title(title)
  plt.show()

# %% [markdown]
# #### Model SVM

# %%
# SVM
from sklearn.svm import SVC

# %%
svc = SVC(kernel='linear')
svc.fit(X_train, y_train) #training svc model
y_pred_svc = svc.predict(X_test) # predicting test data

# %%
print(svc.score(X_train, y_train))
print(svc.score(X_test, y_test))
# Out:
# 0.9230633180049522
# 0.8514851485148515

# %%
print_conf(y_test, y_pred_svc, [1, 2, 3], title="Confusion matrix SVC")

# %%
print(metrics.classification_report(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.80      0.82      0.81       492
#            2       0.79      0.76      0.77       468
#            3       0.97      0.97      0.97       454
#
#     accuracy                           0.85      1414
#    macro avg       0.85      0.85      0.85      1414
# weighted avg       0.85      0.85      0.85      1414

# %% [markdown]
# #### Model XGBOOST

# %%
# XGBOOST
from xgboost import XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train) #training XGBOOST model
y_pred_xgb = xgb.predict(X_test) # predicting test data

# %%
print(xgb.score(X_train, y_train))
print(xgb.score(X_test, y_test))
# Out:
# 0.8537318712415989
# 0.8267326732673267

# %%
print_conf(y_test, y_pred_xgb, [0, 1], title="Confusion matrix XGBOOST Classifier")

# %%
print(metrics.classification_report(y_test, y_pred_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.74      0.86      0.80       492
#            2       0.80      0.67      0.73       468
#            3       0.96      0.95      0.95       454
#
#     accuracy                           0.83      1414
#    macro avg       0.83      0.83      0.83      1414
# weighted avg       0.83      0.83      0.83      1414

# %% [markdown]
# #### Model Random SearchCV

# %%
# Random SearchCV
from sklearn.model_selection import RandomizedSearchCV

# %%
params = {'learning_rate': [0.025, 0.05, 0.075, 0.1], #so called `eta` value
          'max_depth': [6, 7, 8],
          'min_child_weight': [i for i in range(1, 11, 2)],
          'n_estimators': [100, 250, 500] #number of trees, change it to 1000 for better results
}

# %%
random_search = RandomizedSearchCV(xgb, param_distributions=params, n_iter=5, scoring='f1', n_jobs=-1, cv=5, verbose=3)

# %%
random_search.fit(tfidf_vector, kategori)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# RandomizedSearchCV(cv=5, estimator=XGBClassifier(objective='multi:softprob'),
#                    n_iter=5, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.025, 0.05, 0.075,
#                                                           0.1],
#                                         'max_depth': [6, 7, 8],
#                                         'min_child_weight': [1, 3, 5, 7, 9],
#                                         'n_estimators': [100, 250, 500]},
#                    scoring='f1', verbose=3)

# %%
random_search.best_estimator_
# Out:
# XGBClassifier(learning_rate=0.025, max_depth=6, min_child_weight=5,
#               n_estimators=250, objective='multi:softprob')

# %%
random_search.best_params_
# Out:
# {'n_estimators': 250,
#  'min_child_weight': 5,
#  'max_depth': 6,
#  'learning_rate': 0.025}

# %%
xgb_rscv = XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
              colsample_bynode=1, colsample_bytree=1, gamma=0,
              learning_rate=0.025, max_delta_step=0, max_depth=6,
              min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
              nthread=None, objective='binary:logistic', random_state=0,
              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
              silent=None, subsample=1, verbosity=1)
xgb_rscv.fit(X_train, y_train) #training svc model
y_pred_xgb_rscv = xgb_rscv.predict(X_test) # Prediksi Data Test

# %%
print(xgb_rscv.score(X_train, y_train))
print(xgb_rscv.score(X_test, y_test))
# Out:
# 0.8825610187477891
# 0.8458274398868458

# %%
print_conf(y_test, y_pred_xgb_rscv, [0, 1], title="Confusion matrix XGBOOST Classifier With RandomizedSearchCV")

# %%
print(metrics.classification_report(y_test, y_pred_xgb_rscv))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.75      0.90      0.82       492
#            2       0.84      0.68      0.75       468
#            3       0.97      0.96      0.97       454
#
#     accuracy                           0.85      1414
#    macro avg       0.85      0.85      0.85      1414
# weighted avg       0.85      0.85      0.84      1414

# %% [markdown]
# #### Komparasi Model

# %%
# Komparasi Model
# Accuracy Comparison
models = ['SVM', 'XGBOOST', 'RandomSearchCV']
accSVMC = metrics.accuracy_score(y_test,y_pred_svc)
accXGB = metrics.accuracy_score(y_test, y_pred_xgb)
accXGB_RSCV = metrics.accuracy_score(y_test, y_pred_xgb_rscv)
accuracies = [accSVMC, accXGB, accXGB_RSCV ]
comp = pd.DataFrame(list(zip(models, accuracies)), columns=['Model', 'Accuracy'])
comp
# Out:
#             Model  Accuracy
# 0             SVM  0.851485
# 1         XGBOOST  0.826733
# 2  RandomSearchCV  0.845827

# %% [markdown]
# #### Menyimpan Model

# %%
import joblib

# %%
# Menyimpan Model dengan akurasi terbaik
joblib.dump(svc, "/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Model/Model Spam SMS SVM.joblib")
joblib.dump(tfidf_vectorizer, "/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Model/Model Spam SMS TF-IDF Vectorizer.joblib")
# Out:
# ["/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Model/Model Spam SMS TF-IDF Vectorizer.joblib"]

# %%
home_data['Prediction'] = svc.predict(tfidf_vectorizer.transform(home_data['Text']))
home_data['Prediction'] = home_data['Prediction'].apply(lambda x: 'Non Spam' if x == 1 else ('Spam' if x == 2 else 'Penipuan'))

# Save new dataframe into csv file
home_data.to_csv("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Dataset/Spam SMS Classification.csv", index=False)

home_data.head()
# Out:
#    Kategori                                               Text  Length  \
# 0         1           Hoaks itu jahat! Kesehatan kita terancam      40
# 1         1  COVID-19 gelombang ketiga? Waspadalah! Segera ...      69
# 2         1  Hambat varian Omicron di Indonesia dengan disi...     124
# 3         1        Walau sudah boleh berkegiatan di luar rumah      43
# 4         1  Vaksinasi lengkap dan booster + disiplin proke...     159
#
#                                            Praproses  \
# 0            hoaks itu jahat kesehatan kita terancam
# 1  covid gelombang ketiga waspadalah segera vaksi...
# 2  hambat varian omicron di indonesia dengan disi...
# 3        walau sudah boleh berkegiatan di luar rumah
# 4  vaksinasi lengkap dan booster disiplin prokes ...
#
#                                                Token  \
# 0     [hoaks, itu, jahat, kesehatan, kita, terancam]
# 1  [covid, gelombang, ketiga, waspadalah, segera,...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3  [walau, sudah, boleh, berkegiatan, di, luar, r...
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              Stemmed  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                           Tidak_Gaul  \
# 0            [hoaks, itu, jahat, sehat, kita, ancam]
# 1  [covid, gelombang, tiga, waspada, segera, vaks...
# 2  [hambat, varian, omicron, di, indonesia, denga...
# 3       [walau, sudah, boleh, giat, di, luar, rumah]
# 4  [vaksinasi, lengkap, dan, booster, disiplin, p...
#
#                                              No_Stop  \
# 0                       [hoaks, jahat, sehat, ancam]
# 1        [covid, gelombang, waspada, vaksin, vaksin]
# 2  [hambat, varian, omicron, indonesia, disiplin,...
# 3                                      [giat, rumah]
# 4  [vaksinasi, lengkap, booster, disiplin, prokes...
#
#                                               Bersih Prediction
# 0                            hoaks jahat sehat ancam   Non Spam
# 1              covid gelombang waspada vaksin vaksin   Non Spam
# 2  hambat varian omicron indonesia disiplin pakai...   Non Spam
# 3                                         giat rumah   Non Spam
# 4  vaksinasi lengkap booster disiplin prokes lind...   Non Spam

# %% [markdown]
# ### Predict New Data
# melakukan prediksi menggunakan data text yang baru

# %%
# Prediksi Data baru
input_SMS = ['Selamat Anda Mendapatkan Informasi Kejutan Jackpot',
             'Beli Isi Ulang Informasi Harga Bersahabat',
             'Ayo Deposit Kuota Kartu Kredit Gratis Harga Darurat']

def preProcessText(texts):
    new_text = []
    for text in texts:
        # text = case_folding(text)
        # text = tokenized(text)
        text = stemming(text)
        text = removeSlang(text)
        text = removeStopWords(text)
        text = ' '.join(text)
        new_text.append(text)

    return new_text

def predictNewData(sms):
    saved_model = joblib.load("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Model/Model Spam SMS SVM.joblib") 
    saved_tfidf = joblib.load("/content/drive/MyDrive/Uni Life's/NLP/UAS NLP/Model/Model Spam SMS TF-IDF Vectorizer.joblib")

    vectorized_sms = saved_tfidf.transform(sms)
    input_prediction = saved_model.predict(vectorized_sms)

    for i in range(len(input_SMS)):
        if input_prediction[i]==1:
            print('Input text:\n', 
                input_SMS[i], 
                '\nPrediction: \nIni Pesan Non Spam!\n')
        elif input_prediction[i]==2:
            print('Input text:\n', 
                input_SMS[i], 
                '\nPrediction: \nIni Pesan Spam!\n')
        else:
            print('Input text:\n', 
                input_SMS[i], 
                "\nPrediction: \nIni Pesan Penipuan!\n")
            
predictNewData(input_SMS)
# Out:
# Input text:
#  Selamat Anda Mendapatkan Informasi Kejutan Jackpot
# Prediction:
# Ini Pesan Penipuan!
#
# Input text:
#  Beli Isi Ulang Informasi Harga Bersahabat
# Prediction:
# Ini Pesan Non Spam!
#
# Input text:
#  Ayo Deposit Kuota Kartu Kredit Gratis Harga Darurat
# Prediction:
# Ini Pesan Spam!
